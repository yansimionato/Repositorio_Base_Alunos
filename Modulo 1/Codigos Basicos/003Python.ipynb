# %% [markdown]
# # Strings

# %% [markdown]
# são usadas principalmente para armazenar informações de texto. Nelas temos uma sequência de caracteres que formam um texto. O Python permmite formar strings com aspas simples ou duplas

# %%
"João"=="JOÃO" # o Python diferencia letras maiúsculas de minúsculas
# Out:
# False

# %%
nome ="Beatriz"
sobrenome = "Gomes"
print(nome + " " + sobrenome)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3447420592.py in <cell line: 0>()
#       1 nome ="Beatriz"
#       2 sobrenome = "Gomes"
# ----> 3 print(nome + " " + sobrenome)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # f-strings

# %% [markdown]
# String literais formatadas

# %%
idade = 20

# %%
print(nome, sobrenome, idade) # as vírgulas são maneiras de chamar variáveis diferentes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1171438223.py in <cell line: 0>()
# ----> 1 print(nome, sobrenome, idade) # as vírgulas são maneiras de chamar variáveis diferentes
#
# TypeError: 'str' object is not callable

# %%
print(f" {nome} {sobrenome} tem {idade} anos." ) # f na frente do print informa que estamos formatando o print

# %%
linguagem = "Python"
print(f"Eu adoro programar em {linguagem}. E, amo mais ganhar muito $$ programando em Python.")

# %% [markdown]
# # String são objetos iteráveis

# %%
nome = "Gabriel" # o python entende uma palavra como uma lista de letras, então, podemos percorrer essa lista e capturar os elementos que desejamos
# uma lista sempre inicia pelo indice ZERO

# %%
print(nome)

# %%
nome[0]

# %%
nome[3]

# %%
nome[-1] # podemos acessar o último elemento de uma lista atráves do indice -1

# %% [markdown]
# # Entrada de dados com a função input()

# %% [markdown]
# é muito comum em programação que o usuário passe algum tipo de dado

# %%
input("Digite seu nome: ")

# %%
nome = input("Digite seu nome:  ")

# %%
print(nome)

# %%
# Para fazer uma operação matemática precisamoos informar qual tipo é o dado
num1 = input("Digite um número: ")
num2= input("Digite outro número: ")
print(num1 + num2)

# %%
# Para fazer uma operação matemática precisamoos informar qual tipo é o dado
num1 =int(input("Digite um número: "))
num2=int(input("Digite outro número: "))
print(num1 + num2)

# %%
soma = num1 + num2
print(soma)

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
media =(nota1 + nota2)/2
print(f"O aluno(a) teve notas {nota1}, {nota2} e sua média é {media}.")

# %% [markdown]
# # Operadores Aritméticos

# %% [markdown]
# Adição (+)

# %%
print(10 + 20)
print(10 + 20.5)
print(10 + 30 + 40)

# %%
print(-89 + 63) # print() é uma função de saída no python
print(23 - 17) # 23 + (-17)
print(23 + (-17))
print(34 - 67) # 34 + (-67)

# %% [markdown]
# Subtração (-)

# %%
print(123 - 87)

# %% [markdown]
# Multplicação (*)

# %%
print(10*2)

# %%
print(2.4 * 2.5)

# %% [markdown]
# Divisão (/)

# %%
print(1000/10)
print(129/23)

# %% [markdown]
# Divisão com resultado inteiro (//)

# %%
print(129//23)

# %% [markdown]
# Exponenciação (**)

# %%
print(2**3)

# %%
print(2**-1)

# %%
print(2**-1.5)

# %% [markdown]
# # Precedência

# %% [markdown]
# 1. Parênteses
# 2. Expoentes
# 3. Multiplicação e Divisão (da esquerda para a direita)
# 5. Somas e subtração

# %%
5 + 25 * 2

# %%
(5 + 25) * 2

# %%
(12 + 3 - 1 * 50/3)

# %% [markdown]
# Radiciação

# %%
4 ** 0.5

# %% [markdown]
# # Hora da Prática

# %% [markdown]
# 1) Crie um código que receba o nome do aluno, duas notas e informe a média do aluno.
# Obs: no seu print deve apresentar o nome do aluno, as duas notas e a média.

# %%
# 1. Crie um código que receba o nome do aluno, duas notas e informe a média do aluno.
# Obs: no seu print deve apresentar o nome do aluno, as duas notas e a média.

nome_aluno = input("Digite o nome do aluno: ")
nota1_aluno = float(input("Digite a primeira nota: "))
nota2_aluno = float(input("Digite a segunda nota: "))

media_aluno = (nota1_aluno + nota2_aluno)/2
print(nome_aluno,nota1_aluno,nota2_aluno,media_aluno)

# print(f"O aluno(a) {nome_aluno} teve notas {nota1_aluno}, {nota2_aluno} e sua média é {media_aluno}.")
# Out:
# Digite o nome do aluno: Bia
# Digite a primeira nota: 4
# Digite a segunda nota: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3286286767.py in <cell line: 0>()
#       7
#       8 media_aluno = (nota1_aluno + nota2_aluno)/2
# ----> 9 print(nome_aluno,nota1_aluno,nota2_aluno,media_aluno)
#      10
#      11 # print(f"O aluno(a) {nome_aluno} teve notas {nota1_aluno}, {nota2_aluno} e sua média é {media_aluno}.")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# 2) Crie um código que receba as medidas de um retângulo e informe o perimetro do mesmo

# %%
altura = float(input("Digite a altura do retângulo: "))
largura = float(input("Digite a largura do retângulo: "))
perimetro = (altura + largura) * 2
print(f"O perímetro do retângulo com altura {altura} e largura {largura} é igual a {perimetro}")

# %%
nome=input("Digite seu nome: ")
# Out:
# Digite seu nome: Ale
